# %%
# causal_graph_likelihood.ipynb
# Fix number of variables (tree roots and leafs), define a search space
# Generate a random DAG
# Generate data from the DAG
# Estimate the hyperparameters
# Compute the likelihood of the data given the DAG
# From the search space select graph of maximum likelihood with
# Random search, MCMC search, Genetic search

# %%
# Generate a random DAG with n variables, r roots and l leafs
import numpy as np
